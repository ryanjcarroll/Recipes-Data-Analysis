# %%
import numpy as np
import pandas as pd
import json
import requests
import re
import bs4
from bs4 import BeautifulSoup as bs

# %% [markdown]
# # Web Scraping from Allrecipes
#
# In order to compile a dataset of recipes for this project, we will first need to use web scraping and build a JSON object.  For this, we will send requests to www.allrecipes.com and parse their recipe cards.

# %%
# set how many pages to scrape recipes from
first_page = 1
last_page = 1

# %%
# create empty json file to store recipe data
data = []
with open('recipes.json','w') as out_file:
    json.dump(data, out_file, indent=4)

# %%
def save_to_json(title, layout, picture, servings, ingredients, method, prep_time, cook_time, additional_time, total_time):
    with open('recipes.json') as in_file:
        data = json.load(in_file)
    
    # if this recipe title already exists in the data, do not add it again
    already_exists = False
    for recipe in data:
        if recipe['title'] == title:
            already_exists = True
    
    # if a new recipe, append to the json object and dump back to the file
    if not already_exists:
        print("Saved: {} ".format(title))
        new_recipe = {}
        new_recipe['title'] = title
        new_recipe['layout'] = layout
        new_recipe['picture'] = picture
        new_recipe['ingredients'] = ingredients
        new_recipe['method'] = method
        new_recipe['servings'] = servings
        new_recipe['prep_time'] = prep_time
        new_recipe['cook_time'] = cook_time
        new_recipe['additional_time'] = additional_time
        new_recipe['total_time'] = total_time

        data.append(new_recipe)
    
        with open('recipes.json', 'w') as out_file:
            json.dump(data, out_file, indent=4)
    else:
        print("Already Exists: {} ".format(title))

# %%
# class JsonBuilder:
#     def __init__(self):
#         self.json = "[]"
        
#     def add(self, title, layout, picture, servings, ingredients, method, 
#             prep_time, cook_time, additional_time, total_time):
        
#         already_exists = False
#         data = json.loads(self.json)
        
#         # see if any recipes exist already by the same name, prevent duplicates
#         for row in data:
#             if title == row['title']:
#                 already_exists = True
#                 break
                
#         if already_exists:
#             print("Already Exists: {} ".format(title))
#         else:
#             new_recipe = {}
#             new_recipe['title'] = title
#             new_recipe['layout'] = layout
#             new_recipe['picture'] = picture
#             new_recipe['ingredients'] = ingredients
#             new_recipe['method'] = method
#             new_recipe['servings'] = servings
#             new_recipe['prep_time'] = prep_time
#             new_recipe['cook_time'] = cook_time
#             new_recipe['additional_time'] = additional_time
#             new_recipe['total_time'] = total_time

#             recipe_as_json = json.dumps(new_recipe)
#             self.json.append(recipe_as_json)
#             print("Recipe Saved: {}".format(title))
        
#     def get_json(self):
#         return self.json

# %% [markdown]
# Note that allrecipes has two different HTML layouts for their recipe pages, a regular layout and a layout which supports shopping for ingredients directly from the recipe page.  These two layouts have the information we need in different locations, so we need to differentiate them.  If the title element we initially search for is set to 'None', we have to instead look for the elements where they would be in the second (shopper) layout.

# %%
builder = JsonBuilder()

# %%
for page in range(first_page, last_page + 1):
    # request the main allrecipes page which lists the top recipes
    source = requests.get("https://www.allrecipes.com/recipes?page=" + str(page))
    print("PARSING PAGE {}".format(page))
    doc = bs(source.text,'html.parser')
    
    # find each recipe linked on the main page, and open their links one by one
    recipe_cards = doc.select('a.fixed-recipe-card__title-link')

    for card in recipe_cards:
        # these are the values we will scrape for.  We first declare them as empty strings and lists
        layout = 0
        ingredients_list = []
        method_list = []
        title, picture = '', ''
        prep_time, cook_time, total_time, additional_time, servings, = '','','','',''
        
        #open the page for each recipe card and parse its html
        recipe_page_source = requests.get(card['href'])        
        recipe_main = bs(recipe_page_source.text,'html.parser')
        
        # search for the values we declared above
        title = recipe_main.select_one('.recipe-summary__h1')
        if title is not None:
            #for ordinary formatting layout (1)
            layout = 1
            title = title.text
            picture = recipe_main.select_one('.rec-photo').attrs['src']
            ingredients = recipe_main.select('.recipe-ingred_txt')
            method = recipe_main.select('.recipe-directions__list--item')
            servings = recipe_main.select_one('#metaRecipeServings')['content']
            
            meta_item_types = recipe_main.select('.prepTime__item--type')
            meta_item_times = recipe_main.select('.prepTime__item--time')
            
            for label, time in zip(meta_item_types, meta_item_times):
                if label.text == 'Prep':
                    prep_time = time.text
                elif label.text =='Cook':
                    cook_time = time.text
                elif label.text == 'Additional':
                    additional_time = time.text
                elif label.text == 'Ready In':
                    total_time = time.text                
                
        # if the title is 'None', then the page must be in the shopper formatting layout
        else:
            # for shopper formatting layout (2)
            layout = 2
            title = recipe_main.select_one('h1.headline.heading-content').text
            picture = recipe_main.select_one('.inner-container > img').attrs['src']
            ingredients = recipe_main.select('span.ingredients-item-name')
            method = recipe_main.select('div.paragraph > p')
            meta_items = recipe_main.select('div.recipe-meta-item')

            for item in meta_items:
                parts = item.select('div')
                header = parts[0].text.strip()
                body = parts[1].text.strip()
                    
                if header == 'prep:':
                    prep_time = body
                elif header =='cook:':
                    cook_time = body
                elif header == 'additional:':
                    additional_time = body
                elif header == 'total:':
                    total_time = body
                elif header == 'Servings:':
                    servings = body
        
        # compile a list of ingredients for the current recipe
        for ingredient in ingredients:
            if ingredient.text != 'Add all ingredients to list' and ingredient.text != '':
                ingredients_list.append(ingredient.text.strip())
            
        # compile a list of method instructions for the current recipe
        for instruction in method:
            method_list.append(instruction.text.strip())
        
#         # add this to the json string being built by our custom JsonBuilder class
#         builder.add(title, 
#                     layout, 
#                     picture, 
#                     servings, 
#                     ingredients_list, 
#                     method_list, 
#                     prep_time, 
#                     cook_time, 
#                     additional_time, 
#                     total_time
#                    )

        # save all data for the current recipe to the json file
        save_to_json(title,
                     layout,
                     picture, 
                     servings,  
                     ingredients_list, 
                     method_list,
                     prep_time,
                     cook_time,
                     additional_time,
                     total_time
                    )
print("FINISHED PARSING")
# Out:
# PARSING PAGE 1
# Already Exists: Shrimp and Zucchini Rice Bowl
# Already Exists: World's Best Lasagna
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-149-46f2a87b7067> in <module>
#      52             ingredients = recipe_main.select('span.ingredients-item-name')
#      53             method = recipe_main.select('div.paragraph > p')
# ---> 54             meta_items = recipe_main.select('div.recipe-meta-item')
#      55
#      56             for item in meta_items:
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in select(self, selector, namespaces, limit, **kwargs)
#    1374             )
#    1375
# -> 1376         return soupsieve.select(selector, self, namespaces, limit, **kwargs)
#    1377
#    1378     # Old names for backwards compatibility
#
# ~\Anaconda3\lib\site-packages\soupsieve\__init__.py in select(select, tag, namespaces, limit, flags, **kwargs)
#     110     """Select the specified tags."""
#     111
# --> 112     return compile(select, namespaces, flags, **kwargs).select(tag, limit)
#     113
#     114
#
# ~\Anaconda3\lib\site-packages\soupsieve\css_match.py in select(self, tag, limit)
#    1311         """Select the specified tags."""
#    1312
# -> 1313         return list(self.iselect(tag, limit))
#    1314
#    1315     def iselect(self, tag, limit=0):
#
# ~\Anaconda3\lib\site-packages\soupsieve\css_match.py in iselect(self, tag, limit)
#    1316         """Iterate the specified tags."""
#    1317
# -> 1318         for el in CSSMatch(self.selectors, tag, self.namespaces, self.flags).select(limit):
#    1319             yield el
#    1320
#
# ~\Anaconda3\lib\site-packages\soupsieve\css_match.py in select(self, limit)
#    1194
#    1195         for child in self.get_descendants(self.tag):
# -> 1196             if self.match(child):
#    1197                 yield child
#    1198                 if limit is not None:
#
# ~\Anaconda3\lib\site-packages\soupsieve\css_match.py in match(self, el)
#    1221         """Match."""
#    1222
# -> 1223         return not self.is_doc(el) and self.is_tag(el) and self.match_selectors(el, self.selectors)
#    1224
#    1225
#
# ~\Anaconda3\lib\site-packages\soupsieve\css_match.py in is_tag(obj)
#      97
#      98         import bs4
# ---> 99         return isinstance(obj, bs4.Tag)
#     100
#     101     @staticmethod
#
# KeyboardInterrupt:

# %% [markdown]
# # Data Analysis
#
# Now we have a JSON object which contains recipe information scraped from the web.  We can use this data and perform some analyses on it.

# %%
#load json object into dataframe
recipes = pd.read_json(r'recipes.json')

# re-order columns
recipes = recipes[['title', 'servings', 'cook_time', 'prep_time', 'additional_time', 
                   'total_time', 'ingredients', 'method', 'layout', 'picture']]
recipes.head(20)
# Out:
#                                          title  servings      cook_time  \
# 0                Shrimp and Zucchini Rice Bowl         4             15
# 1                         World's Best Lasagna        12  2 hrs 30 mins
# 2                  Best Chocolate Chip Cookies        24        10 mins
# 3                              Fluffy Pancakes         4             10
# 4                  Good Old Fashioned Pancakes         8             15
# 5                          Banana Banana Bread        12    1 hr 5 mins
# 6                    Apple Pie by Grandma Ople         8           1 hr
# 7                Delicious Ham and Potato Soup         8             25
# 8                         Banana Crumb Muffins        10        20 mins
# 9                 To Die For Blueberry Muffins         8        25 mins
# 10                               Best Brownies        16        35 mins
# 11                          Chicken Pot Pie IX         8        50 mins
# 12  Best Big, Fat, Chewy Chocolate Chip Cookie        18        15 mins
# 13   Award Winning Soft Chocolate Chip Cookies        72             12
# 14               The Best Rolled Sugar Cookies        60         8 mins
# 15                    Broiled Tilapia Parmesan         8        10 mins
# 16                        Mom's Zucchini Bread        24           1 hr
# 17                Downeast Maine Pumpkin Bread        24        50 mins
# 18               Awesome Slow Cooker Pot Roast        12          8 hrs
# 19           Slow Cooker Chicken and Dumplings         8          6 hrs
#
#    prep_time additional_time     total_time  \
# 0         10                             25
# 1    30 mins         15 mins  3 hrs 15 mins
# 2    20 mins         30 mins           1 hr
# 3         10                             25
# 4          5                             20
# 5    15 mins                   1 hr 20 mins
# 6    30 mins                   1 hr 30 mins
# 7         20                             45
# 8    15 mins                        35 mins
# 9    15 mins                        40 mins
# 10   25 mins                           1 hr
# 11   20 mins                   1 hr 10 mins
# 12   10 mins         15 mins        40 mins
# 13        15                              1
# 14   20 mins   2 hrs 32 mins          3 hrs
# 15    5 mins                        15 mins
# 16   20 mins         20 mins   1 hr 40 mins
# 17   15 mins                    1 hr 5 mins
# 18   10 mins                  8 hrs 10 mins
# 19   10 mins                  6 hrs 10 mins
#
#                                           ingredients  \
# 0   [2 tablespoons olive oil, divided, 2 cups slic...
# 1   [1 pound sweet Italian sausage, ¾ pound lean g...
# 2   [1 cup butter, softened, 1 cup white sugar, 1 ...
# 3   [3/4 cup milk, 2 tablespoons white vinegar, 1 ...
# 4   [1 1/2 cups all-purpose flour, 3 1/2 teaspoons...
# 5   [2 cups all-purpose flour, 1 teaspoon baking s...
# 6   [1 recipe pastry for a 9 inch double crust pie...
# 7   [3 1/2 cups peeled and diced potatoes, 1/3 cup...
# 8   [1 ½ cups all-purpose flour, 1 teaspoon baking...
# 9   [1 ½ cups all-purpose flour, ¾ cup white sugar...
# 10  [½ cup butter, 1 cup white sugar, 2  eggs, 1 t...
# 11  [1 pound skinless, boneless chicken breast hal...
# 12  [2 cups all-purpose flour, ½ teaspoon baking s...
# 13  [4 1/2 cups all-purpose flour, 2 teaspoons bak...
# 14  [1 ½ cups butter, softened, 2 cups white sugar...
# 15  [½ cup Parmesan cheese, ¼ cup butter, softened...
# 16  [3 cups all-purpose flour, 1 teaspoon salt, 1 ...
# 17  [1 (15 ounce) can pumpkin puree, 4  eggs, 1 cu...
# 18  [2 (10.75 ounce) cans condensed cream of mushr...
# 19  [4   skinless, boneless chicken breast halves,...
#
#                                                method  layout  \
# 0   [Heat 1 tablespoon oil in a large skillet over...       1
# 1   [In a Dutch oven, cook sausage, ground beef, o...       2
# 2   [Preheat oven to 350 degrees F (175 degrees C)...       2
# 3   [Combine milk with vinegar in a medium bowl an...       1
# 4   [In a large bowl, sift together the flour, bak...       1
# 5   [Preheat oven to 350 degrees F (175 degrees C)...       2
# 6   [Preheat oven to 425 degrees F (220 degrees C)...       2
# 7   [Combine the potatoes, celery, onion, ham and ...       1
# 8   [Preheat oven to 375 degrees F (190 degrees C)...       2
# 9   [Preheat oven to 400 degrees F (200 degrees C)...       2
# 10  [Preheat oven to 350 degrees F (175 degrees C)...       2
# 11  [Preheat oven to 425 degrees F (220 degrees C....       2
# 12  [Preheat the oven to 325 degrees F (165 degree...       2
# 13  [Preheat oven to 350 degrees F (175 degrees C)...       1
# 14  [In a large bowl, cream together butter and su...       2
# 15  [Preheat your oven's broiler. Grease a broilin...       2
# 16  [Grease and flour two 8 x 4 inch pans.  Prehea...       2
# 17  [Preheat oven to 350 degrees F (175 degrees C)...       2
# 18  [In a slow cooker, mix cream of mushroom soup,...       2
# 19  [Place the chicken, butter, soup, and onion in...       2
#
#                                               picture
# 0   https://images.media-allrecipes.com/userphotos...
# 1   https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 2   https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 3   https://images.media-allrecipes.com/userphotos...
# 4   https://images.media-allrecipes.com/userphotos...
# 5   https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 6   https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 7   https://images.media-allrecipes.com/userphotos...
# 8   https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 9   https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 10  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 11  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 12  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 13  https://images.media-allrecipes.com/userphotos...
# 14  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 15  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 16  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 17  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 18  https://imagesvc.meredithcorp.io/v3/mm/image?u...
# 19  https://imagesvc.meredithcorp.io/v3/mm/image?u...

# %% [markdown]
# ### Analyzing Ingredients
#
# Let's look at the ingredients that compose each recipe a bit more closely.  First, we want to know what the most common ingredients are among our scraped recipes.

# %%
all_ingredients_list = []

for row in recipes['ingredients']:
    for ing in row:
        all_ingredients_list.append(ing)

# %%
ingredients = pd.DataFrame(all_ingredients_list, columns=['ingredients'])
ingredients['edited'] = ingredients['ingredients']
ingredients.head()
# Out:
#                                          ingredients  \
# 0                   2 tablespoons olive oil, divided
# 1                         2 cups sliced green onions
# 2                         1/4 teaspoon salt, divided
# 3  2 (8.8 ounce) packages UNCLE BEN'S® READY RICE...
# 4                         2 1/2 cups sliced zucchini
#
#                                               edited
# 0                   2 tablespoons olive oil, divided
# 1                         2 cups sliced green onions
# 2                         1/4 teaspoon salt, divided
# 3  2 (8.8 ounce) packages UNCLE BEN'S® READY RICE...
# 4                         2 1/2 cups sliced zucchini

# %% [markdown]
# Now we attempt to clean the ingredients list to get rid of the 'noise' and have a raw list of ingredient names without units, numbers or descriptors.

# %%
# lists of common words we want to remove
units = ['gallon','quart','pint','cup','teaspoon','tablespoon','ounce','pound','can','pinch','serving','slice','package','bottle']
descriptors = ['small','medium','large']

# remove common measuring and descriptive words
for word in units + descriptors:
    plural = word+"s"
    ingredients['edited'] = ingredients['edited'].str.replace(' '+plural+' ', ' ')
    ingredients['edited'] = ingredients['edited'].str.replace(' '+word+' ','')

# remove parantheicals
ingredients['edited'] = ingredients['edited'].str.replace(r'\([^()]*\)','')
# remove text after commas and hyphens
ingredients['edited'] = ingredients['edited'].str.partition(',')
ingredients['edited'] = ingredients['edited'].str.partition(',')
# remove non-alphabetical characters
ingredients['edited'] = ingredients['edited'].str.replace('[^a-zA-Z]', ' ')

# edit down extra spaces caused by adjacent removals
ingredients['edited'] = ingredients['edited'].str.strip()

ingredients.head()
# Out:
#                                          ingredients  \
# 0                   2 tablespoons olive oil, divided
# 1                         2 cups sliced green onions
# 2                         1/4 teaspoon salt, divided
# 3  2 (8.8 ounce) packages UNCLE BEN'S® READY RICE...
# 4                         2 1/2 cups sliced zucchini
#
#                                             edited
# 0                                        olive oil
# 1                              sliced green onions
# 2                                             salt
# 3  UNCLE BEN S  READY RICE  Whole Grain Brown Rice
# 4                                  sliced zucchini

# %% [markdown]
# From here we can investigate which ingredients are the most common.  First, we see which edited rows appear most commonly with a call to .value_counts()

# %%
ingredients['edited'].value_counts().head(20)
# Out:
# all purpose flour            18
# butter                       16
# salt                         16
# white sugar                  15
# baking soda                   9
# vanilla extract               8
# eggs                          8
# baking powder                 7
# egg                           6
# water                         5
# packed brown sugar            5
# milk                          5
# chopped walnuts               4
# ground cinnamon               4
# unsalted butter               3
# vegetable oil                 3
# semisweet chocolate chips     3
# skinless                      2
# bananas                       2
# cloves garlic                 2
# Name: edited, dtype: int64

# %% [markdown]
# This shows us the most common row values.  However, this data has a few flaws.  Primarily, the issue is that we need the entire row to match to be counted together.  For instance, 'sugar' and 'white sugar' are counted seperately in this analysis.
#
# Another approach might be to store the list of all ingredient 'words' in its own dataframe, and perform a value_counts on it to see what the most common non-unit, non-descriptive words are in our recipe ingredients.  This loses some specificity (we lose the distinction between 'white sugar' and 'brown sugar'), but is helpful in other contexts.

# %%
ingredient_words_list = []
for row in ingredients['edited']:
    for word in row.split():
        ingredient_words_list.append(word)

ingredient_words = pd.DataFrame(ingredient_words_list,columns=['words'])

# %%
ingredient_words['words'].value_counts().head(20)
# Out:
# sugar      22
# butter     19
# flour      18
# purpose    18
# all        18
# salt       17
# white      17
# baking     16
# ground     11
# powder     10
# vanilla     9
# soda        9
# eggs        8
# extract     8
# chopped     8
# egg         7
# brown       6
# onion       6
# water       6
# packed      5
# Name: words, dtype: int64
