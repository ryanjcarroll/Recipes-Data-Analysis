# %%
import numpy as np
import pandas as pd
import requests
import json
import bs4
from bs4 import BeautifulSoup as bs

# %% [markdown]
# # Web Scraping from Allrecipes.com
#
# In order to compile a dataset of recipes for this project, we will first need to use web scraping and build a JSON object.  For this, we will send requests to www.allrecipes.com and parse their recipe cards.

# %% [markdown]
# ### Setup

# %%
# set how many pages to scrape recipes from
first_page = 50
last_page = 60

# %%
def save_to_json(title, layout, picture, servings, ingredients, method, prep_time, cook_time, additional_time, total_time):
    with open('recipes.json') as in_file:
        data = json.load(in_file)
    
    # if this recipe title already exists in the data, do not add it again
    already_exists = False
    for recipe in data:
        if recipe['title'] == title:
            already_exists = True
    
    # if a new recipe, append to the json object and dump back to the file
    if not already_exists:
        print("Saved: {} ".format(title))
        new_recipe = {}
        new_recipe['title'] = title
        new_recipe['layout'] = layout
        new_recipe['picture'] = picture
        new_recipe['ingredients'] = ingredients
        new_recipe['method'] = method
        new_recipe['servings'] = servings
        new_recipe['prep_time'] = prep_time
        new_recipe['cook_time'] = cook_time
        new_recipe['additional_time'] = additional_time
        new_recipe['total_time'] = total_time

        data.append(new_recipe)
    
        with open('recipes.json', 'w') as out_file:
            json.dump(data, out_file, indent=4)
    else:
        print("Already Exists: {} ".format(title))

# %% [markdown]
# ### The Web Scraper
#
# Note that allrecipes has two different HTML layouts for their recipe pages, a regular layout and a layout which supports shopping for ingredients directly from the recipe page.  These two layouts have the information we need in different locations, so we need to differentiate them.  If the title element we initially search for is set to 'None', we have to instead look for the elements where they would be in the second (shopper) layout.

# %%
for page in range(first_page, last_page + 1):
    # request the main allrecipes page which lists the top recipes
    source = requests.get("https://www.allrecipes.com/recipes?page=" + str(page))
    print("PARSING PAGE {}".format(page))
    doc = bs(source.text,'html.parser')
    
    # find each recipe linked on the main page, and open their links one by one
    recipe_cards = doc.select('a.fixed-recipe-card__title-link')

    for card in recipe_cards:
        # these are the values we will scrape for.  We first declare them as empty strings and lists
        layout = 0
        ingredients_list = []
        method_list = []
        title, picture = '', ''
        prep_time, cook_time, total_time, additional_time, servings, = '','','','',''
        
        #open the page for each recipe card and parse its html
        recipe_page_source = requests.get(card['href'])        
        recipe_main = bs(recipe_page_source.text,'html.parser')
        
        # search for the values we declared above
        title = recipe_main.select_one('.recipe-summary__h1')
        if title is not None:
            #for ordinary formatting layout (1)
            layout = 1
            title = title.text
            picture = recipe_main.select_one('.rec-photo').attrs['src']
            ingredients = recipe_main.select('.recipe-ingred_txt')
            method = recipe_main.select('.recipe-directions__list--item')
            servings = recipe_main.select_one('#metaRecipeServings')['content']
            
            meta_item_types = recipe_main.select('.prepTime__item--type')
            meta_item_times = recipe_main.select('.prepTime__item--time')
            
            for label, time in zip(meta_item_types, meta_item_times):
                if label.text == 'Prep':
                    prep_time = time.text
                elif label.text =='Cook':
                    cook_time = time.text
                elif label.text == 'Additional':
                    additional_time = time.text
                elif label.text == 'Ready In':
                    total_time = time.text                
                
        # if the title is 'None', then the page must be in the shopper formatting layout
        else:
            # for shopper formatting layout (2)
            layout = 2
            title = recipe_main.select_one('h1.headline.heading-content').text
            picture = recipe_main.select_one('.inner-container > img').attrs['src']
            ingredients = recipe_main.select('span.ingredients-item-name')
            method = recipe_main.select('div.paragraph > p')
            meta_items = recipe_main.select('div.recipe-meta-item')
            
            for item in meta_items:
                parts = item.select('div')
                header = parts[0].text.strip()
                body = parts[1].text.strip()
                    
                if header == 'prep:':
                    prep_time = body
                elif header =='cook:':
                    cook_time = body
                elif header == 'additional:':
                    additional_time = body
                elif header == 'total:':
                    total_time = body
                elif header == 'Servings:':
                    servings = body
        
        # compile a list of ingredients for the current recipe
        for ingredient in ingredients:
            if ingredient.text != 'Add all ingredients to list' and ingredient.text != '':
                ingredients_list.append(ingredient.text.strip())
            
        # compile a list of method instructions for the current recipe
        for instruction in method:
            method_list.append(instruction.text.strip())
        
        # do not save if ingredients and method lists are empty (video recipes)
        if len(ingredients_list)==0 and len(method_list) == 0:
            pass
        else:
            # add this to the json string being built by our custom JsonBuilder class
            save_to_json(title, 
                        layout, 
                        picture, 
                        servings, 
                        ingredients_list, 
                        method_list, 
                        prep_time, 
                        cook_time, 
                        additional_time, 
                        total_time
                       )
        
print("FINISHED PARSING")
# Out:
# PARSING PAGE 50
# Already Exists: Rhubarb and Strawberry Pie
# Already Exists: Pineapple Upside-Down Cake VII
# Already Exists: Asian Glazed Chicken Thighs
# Already Exists: Mushrooms with a Soy Sauce Glaze
# Already Exists: Greek Lemon Chicken and Potatoes
# Already Exists: Vegan Chocolate Cake
# Already Exists: Apple Butter Pork Loin
# Already Exists: Easy Sausage Gravy and Biscuits
# Already Exists: Best of the Best Blueberry Muffins
# Already Exists: Restaurant-Style Hashbrown Casserole
# Already Exists: Baked Lemon Chicken with Mushroom Sauce
# Already Exists: Buckeye Balls II
# Already Exists: Pesto Cheesy Chicken Rolls
# Already Exists: Sarge's EZ Pulled Pork BBQ
# Already Exists: Egg and Sausage Casserole
# Already Exists: Sauteed Garlic Asparagus
# Already Exists: Broccoli Chicken Casserole I
# Already Exists: Oven Pot Roast
# Already Exists: Grilled Tilapia with Mango Salsa
# Saved: Apple Crisp with Oat Topping
# PARSING PAGE 51
# Already Exists: Fried Cabbage II
# Saved: A-Number-1 Banana Cake
# Saved: Chinese Pepper Steak
# Saved: Whole Wheat Honey Bread
# Saved: Almost No Fat Banana Bread
# Saved: Spicy Thai Basil Chicken (Pad Krapow Gai)
# Saved: Slow Cooker Enchiladas
# Saved: Caramel Shortbread Squares
# Saved: Egg Noodles
# Saved: One Pan Orecchiette Pasta
# Saved: Triple Dipped Fried Chicken
# Saved: Cream Cheese Penguins
# Saved: Red Enchilada Sauce
# Saved: Zucchini-Chocolate Chip Muffins
# Saved: Slow Cooker Chicken Cacciatore
# Saved: Alice Chicken
# Saved: Garbanzo Bean Chocolate Cake (Gluten Free!)
# Saved: Bob's Awesome Lasagna
# Saved: The Best Potato Salad
# Saved: The Best Banana Pudding
# PARSING PAGE 52
# Saved: Chris' Bay Area Burger
# Saved: Butternut Squash Bisque
# Saved: Strawberry Angel Food Dessert
# Saved: Broccoli Rice Casserole
# Saved: Beefy Baked Ravioli
# Saved: Tangy Honey Glazed Ham
# Saved: Peanut Butter Banana Smoothie
# Saved: Best Fried Green Tomatoes
# Saved: Grandma's Corn Pudding
# Saved: Southern Candied Sweet Potatoes
# Saved: Peppy's Pita Bread
# Saved: Lemon Cream Pasta with Chicken
# Saved: Garlic Chicken with Orzo Noodles
# Saved: BLT Salad
# Saved: Salsa Chicken Burrito Filling
# Saved: French Dip Sandwiches
# Saved: Cake Mix Cookies VIII
# Saved: Chewy Granola Bars
# Saved: Corn Dogs
# Saved: Homemade Crispy Seasoned French Fries
# PARSING PAGE 53
# Saved: Lana's Sweet and Sour Meatballs
# Saved: Chicken Wild Rice Soup I
# Saved: Pumpkin Cream Cheese Muffins
# Saved: Beer Bread I
# Saved: Cake Mix Cookies IV
# Saved: Black Bean Brownies
# Saved: Real Italian Calzones
# Saved: Becky's Chicken Salad
# Saved: Pretty Chicken Marinade
# Saved: Creamy Herbed Pork Chops
# Saved: Whole Grain Waffles
# Saved: German Chocolate Cake III
# Saved: Magic Cookie Bars from EAGLE BRAND®
# Saved: Chocolate Chip Banana Bread II
# Saved: Vanilla Crepes
# Saved: Spicy Rapid Roast Chicken
# Saved: Oven Fried Parmesan Chicken
# Saved: Country Fried Steak and Milk Gravy
# Saved: Easy Granola Bars
# Saved: Quick and Easy Mexican Chicken
# PARSING PAGE 54
# Saved: Health Nut Blueberry Muffins
# Saved: Grilled Asparagus
# Saved: Candied Sweet Potatoes
# Saved: Light Oat Bread
# Saved: Orange Cake
# Saved: Modenese Pork Chops
# Saved: Happy Shrimp
# Saved: Southern Pimento Cheese
# Saved: Apple Enchilada Dessert
# Saved: Suzy's Mashed Red Potatoes
# Saved: Seven Layer Tortilla Pie
# Saved: Shrimp Fettuccine Alfredo
# Saved: Pineapple Chicken Tenders
# Saved: White Bread For The Bread Machine
# Saved: The Whole Jar of Peanut Butter Cookies
# Saved: Turkey Veggie Meatloaf Cups
# Saved: Caramels
# Saved: Broccoli Cheese Soup V
# Saved: Bread Machine Bagels
# Saved: Marbled Pumpkin Cheesecake
# PARSING PAGE 55
# Already Exists: Marbled Pumpkin Cheesecake
# Saved: Jennie's Heavenly Slow Cooker Chicken
# Saved: Grandma's Chicken Chardon
# Saved: Tantalizingly Tangy Meatloaf
# Saved: Easy Beef Stroganoff
# Saved: Easy Cheesy Chicken I
# Saved: Vegan Pancakes
# Saved: Black Bottom Cupcakes I
# Saved: Apple Pie Muffins
# Saved: Ethiopian Cabbage Dish
# Saved: German Potato Pancakes
# Saved: Perfect Baked Potato
# Saved: Braised Corned Beef Brisket
# Saved: Asian Salmon
# Saved: Pat's Baked Beans
# Saved: Bacon Wrapped Hamburgers
# Saved: Golden Pork Chops
# Saved: Simple Beef Stroganoff
# Saved: Sweet and Sour Sauce I
# Saved: Crispy Herb Baked Chicken
# PARSING PAGE 56
# Saved: Sweet and Spicy Green Beans
# Saved: Caramel Filled Chocolate Cookies
# Saved: Blueberry Crumb Bars
# Saved: Portobello Penne Pasta Casserole
# Saved: Cioppino
# Saved: Grilled Shrimp Scampi
# Saved: Beef Stroganoff for Instant Pot®
# Saved: Beth's Chocolate Chip Cookies
# Saved: Candied Carrots
# Saved: Spooky Witches' Fingers
# Saved: Easy Pumpkin Muffins
# Saved: Chocolate Chip Pumpkin Bread
# Saved: Fresh Strawberry Upside Down Cake
# Saved: Penne with Chicken and Pesto
# Saved: Chocolate Mint Candies Cookies
# Saved: Easy Cheese Ball II
# Saved: Cinnamon Raisin Bread I
# Saved: Slow Cooker Lentil and Ham Soup
# Saved: Valentino's Pizza Crust
# Saved: Roast Chicken with Rosemary
# PARSING PAGE 57
# Saved: Three Cheese Garlic Scalloped Potatoes
# Saved: Lemon Pie Bars
# Saved: Chicken Wing Dip
# Saved: Layered Chicken and Black Bean Enchilada Casserole
# Saved: Pork Chops Stuffed with Smoked Gouda and Bacon
# Saved: Out of this World Turkey Brine
# Saved: Easy Caramelized Onion Pork Chops
# Saved: Slow Cooker Adobo Chicken
# Saved: Spinach and Orzo Salad
# Saved: Cream of Fresh Asparagus Soup II
# Saved: Juicy Thanksgiving Turkey
# Saved: Hot Fudge Ice Cream Bar Dessert
# Saved: Strawberry Jam
# Saved: Baked Chicken Wings
# Saved: Fajita Marinade I
# Saved: Bacon for the Family or a Crowd
# Saved: Jenn's Out Of This World Spaghetti and Meatballs
# Saved: Urban Legend Chocolate Chip Cookies
# Saved: Mamaw's Chicken and Rice Casserole
# Saved: Baked Ham and Cheese Party Sandwiches
# PARSING PAGE 58
# Saved: Slow Cooked Corned Beef for Sandwiches
# Already Exists: Spinach and Feta Turkey Burgers
# Saved: Chef John's Banana Bread
# Saved: Red Garlic Mashed Potatoes
# Saved: Gourmet Chicken Pizza
# Saved: Tater Tot Taco Casserole
# Saved: Chicken Katsu
# Saved: Chicken Tetrazzini IV
# Saved: Kielbasa and Cabbage
# Saved: Hot Pizza Dip
# Saved: White Chocolate Chip Oatmeal Cookies
# Saved: Luscious Spinach Artichoke Dip
# Saved: Oregon Salmon Patties
# Saved: Spanakopita (Greek Spinach Pie)
# Saved: World's Best Potato Salad
# Saved: Salmon Chowder
# Saved: Campbell's® Green Bean Casserole
# Saved: Basic Corn Muffins
# Saved: Classic Tiramisu
# Saved: Best Black Beans
# PARSING PAGE 59
# Saved: Chef John's Pumpkin Pie
# Saved: Baked Spaghetti I
# Saved: Outrageous Warm Chicken Nacho Dip
# Saved: Pasta Primavera with Italian Turkey Sausage
# Saved: Cheese and Bacon Potato Rounds
# Saved: Grilled Cheese Sandwich
# Saved: Master Pizza Dough
# Saved: Cranberry Hootycreeks
# Saved: Skillet Pork Chops with Potatoes and Onion
# Saved: Magic Peanut Butter Middles
# Saved: Salmon with Lemon and Dill
# Saved: The Best Steak Marinade
# Saved: Lentil Soup with Lemon
# Saved: Easier Chicken Marsala
# Saved: Pork Marsala
# Saved: Creamy Blueberry Pie
# Saved: Avocado Feta Salsa
# Saved: Sweet Cornbread Cake
# Saved: Roasted Pumpkin Seeds
# Saved: Irish Soda Bread
# PARSING PAGE 60
# Saved: Bill's Blue Cheese Dressing
# Saved: Oatmeal Chocolate Chip Cookies I
# Saved: Barbecue Beef Cups
# Saved: Easy Alfredo Sauce I
# Saved: Boudreaux's Zydeco Stomp Gumbo
# Saved: Light and Fluffy Spinach Quiche
# Saved: Hawaiian Chicken Kabobs
# Saved: Baked Corn
# Saved: Garlic Mashed Cauliflower
# Saved: Uglies
# Saved: Churros
# Saved: Easy and Elegant Pork Tenderloin
# Saved: Diane's Colcannon
# Saved: Lime Cilantro Rice
# Saved: Greek Lemon Chicken and Potato Bake
# Saved: Fried Mozzarella Cheese Sticks
# Saved: Andrea's Pasta Fagioli
# Saved: Pork Tenderloin with Dijon Marsala Sauce
# Saved: Grilled Lemon Herb Pork Chops
# Saved: Quick Baked Zucchini Chips
# FINISHED PARSING
